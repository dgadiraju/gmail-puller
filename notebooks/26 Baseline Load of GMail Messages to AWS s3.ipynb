# %%
import boto3

dynamodb = boto3.resource('dynamodb')
table = dynamodb.Table('gmail_jobs')
table.delete_item(Key={'job_id': 'gmail_jobs'})
item = {
    'job_id': 'gmail_ingest',
    'job_description': 'Ingest data from gmail to s3',
    'is_active': 'Y',
    'baseline_days': 45
}
table.put_item(Item=item)
# Out:
# {'ResponseMetadata': {'RequestId': '37L350HB28LD8TL1LR3AJR6ML3VV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Sun, 15 May 2022 10:53:45 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '37L350HB28LD8TL1LR3AJR6ML3VV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2745614147'},
#   'RetryAttempts': 0}}

# %%
# !aws s3 rm s3://itversitydata/messages --recursive

# %%
import boto3
import pickle


def get_creds():
    sm_client = boto3.client(
        'secretsmanager',
        region_name='us-east-1'
    )

    secret_token = sm_client.get_secret_value(SecretId='gmail_token')['SecretBinary']
    creds = pickle.loads(secret_token)
    return creds

# %%
from googleapiclient.discovery import build

def get_users():
    creds = get_creds()
    service = build('gmail', 'v1', credentials=creds)
    return service.users()

# %%
def get_job_details(job_name):
    dynamodb = boto3.resource('dynamodb')
    table = dynamodb.Table('gmail_jobs')
    job_details = table.get_item(Key={'job_id': job_name})['Item']
    return job_details

# %%
import datetime
import time

def get_job_run_time_range(job_details):
    job_start_time = int(time.mktime(datetime.datetime.now().timetuple()))
    if job_details.get('job_run_bookmark_details'):
        job_run_bookmark_details = job_details.get('job_run_bookmark_details')
        last_run_start_time_epoch = int(job_run_bookmark_details['last_run_start_time_epoch'])
        last_run_end_time_epoch = int(job_run_bookmark_details['last_run_end_time_epoch'])
        last_run_diff = datetime.datetime.now().date() - datetime.datetime.fromtimestamp(last_run_end_time_epoch).date()
        if last_run_diff.days > 1:
            start_time_epoch = last_run_end_time_epoch
            end_time = datetime.datetime.fromtimestamp(last_run_end_time_epoch).date() + datetime.timedelta(days=1)
            end_time_epoch = int(time.mktime(end_time.timetuple()))
        else:
            start_time_epoch = last_run_end_time_epoch
            end_time_epoch = int(time.mktime(datetime.datetime.now().timetuple()))  
    else:
        baseline_days = int(job_details['baseline_days'])
        start_time = datetime.datetime.now().date() - datetime.timedelta(days=int(baseline_days))
        end_time = start_time + datetime.timedelta(days=1)
        start_time_epoch = int(time.mktime(start_time.timetuple()))
        end_time_epoch = int(time.mktime(end_time.timetuple()))
    return job_start_time, start_time_epoch, end_time_epoch

# %%
def get_message_ids(start_time_epoch, end_time_epoch):
    message_ids = []
    next_page_token = None

    users = get_users()
    while True:
        if next_page_token:
            print(f'Processing in range between {start_time_epoch} and {end_time_epoch} using token {next_page_token}')
            messages = users. \
                messages(). \
                list(
                    userId='me', 
                    q=f'after:{start_time_epoch} before:{end_time_epoch}',
                    pageToken=next_page_token
                ). \
                execute()
            message_ids += messages['messages']
            next_page_token = messages.get('nextPageToken')
        else:
            print(f'Processing in range between {start_time_epoch} and {end_time_epoch}')
            messages = users. \
                messages(). \
                list(
                    userId='me', 
                    q=f'after:{start_time_epoch} before:{end_time_epoch}'
                ). \
                execute()
            message_ids = messages['messages']
            next_page_token = messages.get('nextPageToken')
        if next_page_token == None:
            break
    return message_ids

# %%
import pandas as pd

def get_messages(message_ids):
    users = get_users()
    messages = []
    for message_id in message_ids:
        message = users.messages().get(userId='me', id=message_id['id']).execute()
        messages.append(message)
    return pd.DataFrame(messages)

# %%
import uuid


def write_messages_to_s3(messages_df, s3_bucket, s3_prefix):
    messages_df.to_json(f's3://{s3_bucket}/{s3_prefix}/part-{uuid.uuid1()}.json', orient='records', lines=True)
    print(f'Successfully saved messages to s3://{s3_bucket}/{s3_prefix}/part-{uuid.uuid1()}.json')

# %%
def save_job_run_details(job_details, job_start_time, message_ids, start_time_epoch, end_time_epoch, file_name):
    dynamodb = boto3.resource('dynamodb')
    message_count = len(message_ids)
    max_message_id = max([message_id['id'] for message_id in message_ids])
    job_run_details_item = {
        'job_id': job_details['job_id'],
        'job_run_time': job_start_time,
        'job_run_bookmark_details': {
            'max_message_id': max_message_id,
            'start_time_epoch': start_time_epoch,
            'end_time_epoch': end_time_epoch
        },
        'rows_processed': message_count,
        'file_name': file_name
    }
    job_run_details_table = dynamodb.Table('gmail_job_run_details')
    job_run_details_table.put_item(Item=job_run_details_item)
    
    job_details_table = dynamodb.Table('gmail_jobs')
    job_details['job_run_bookmark_details'] = {
        'last_run_max_message_id': max_message_id,
        'last_run_start_time_epoch': start_time_epoch,
        'last_run_end_time_epoch': end_time_epoch 
    }
    job_details_table.put_item(Item=job_details)

# %%
# %%time

while True:
    job_details = get_job_details('gmail_ingest')
    job_start_time, start_time_epoch, end_time_epoch = get_job_run_time_range(job_details)
    current_date_epoch = int(time.mktime(datetime.datetime.now().date().timetuple()))

    if end_time_epoch > current_date_epoch:
        break
    message_ids = get_message_ids(start_time_epoch, end_time_epoch)
    messages = get_messages(message_ids)
    file_name = write_messages_to_s3(messages, 'itversitydata', 'messages')
    save_job_run_details(job_details, job_start_time, message_ids, start_time_epoch, end_time_epoch, file_name)
# Out:
# Processing in range between 1648665000 and 1648751400
# Successfully saved messages to s3://itversitydata/messages/part-94b6631a-d43d-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1648751400 and 1648837800
# Successfully saved messages to s3://itversitydata/messages/part-b34aa7dc-d43d-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1648837800 and 1648924200
# Successfully saved messages to s3://itversitydata/messages/part-c925e012-d43d-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1648924200 and 1649010600
# Successfully saved messages to s3://itversitydata/messages/part-da42165e-d43d-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649010600 and 1649097000
# Successfully saved messages to s3://itversitydata/messages/part-f055c774-d43d-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649097000 and 1649183400
# Processing in range between 1649097000 and 1649183400 using token 10277798134644464037
# Successfully saved messages to s3://itversitydata/messages/part-132c9b06-d43e-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649183400 and 1649269800
# Successfully saved messages to s3://itversitydata/messages/part-347a9e0c-d43e-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649269800 and 1649356200
# Successfully saved messages to s3://itversitydata/messages/part-5279d616-d43e-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649356200 and 1649442600
# Successfully saved messages to s3://itversitydata/messages/part-6f72497e-d43e-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649442600 and 1649529000
# Successfully saved messages to s3://itversitydata/messages/part-7fa3770a-d43e-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649529000 and 1649615400
# Successfully saved messages to s3://itversitydata/messages/part-925c49bc-d43e-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649615400 and 1649701800
# Successfully saved messages to s3://itversitydata/messages/part-acac00f0-d43e-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649701800 and 1649788200
# Successfully saved messages to s3://itversitydata/messages/part-c595bf48-d43e-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649788200 and 1649874600
# Processing in range between 1649788200 and 1649874600 using token 06526021984923969402
# Successfully saved messages to s3://itversitydata/messages/part-e88fee74-d43e-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649874600 and 1649961000
# Processing in range between 1649874600 and 1649961000 using token 16248182393472268855
# Successfully saved messages to s3://itversitydata/messages/part-0e2c14c8-d43f-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1649961000 and 1650047400
# Successfully saved messages to s3://itversitydata/messages/part-2590cd48-d43f-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650047400 and 1650133800
# Successfully saved messages to s3://itversitydata/messages/part-3635d8be-d43f-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650133800 and 1650220200
# Successfully saved messages to s3://itversitydata/messages/part-4a3e96f2-d43f-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650220200 and 1650306600
# Successfully saved messages to s3://itversitydata/messages/part-6773442a-d43f-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650306600 and 1650393000
# Successfully saved messages to s3://itversitydata/messages/part-89b06888-d43f-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650393000 and 1650479400
# Processing in range between 1650393000 and 1650479400 using token 02966412517368776189
# Successfully saved messages to s3://itversitydata/messages/part-ad60cd22-d43f-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650479400 and 1650565800
# Successfully saved messages to s3://itversitydata/messages/part-cdd65f90-d43f-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650565800 and 1650652200
# Successfully saved messages to s3://itversitydata/messages/part-ebbf053e-d43f-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650652200 and 1650738600
# Successfully saved messages to s3://itversitydata/messages/part-00ae83de-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650738600 and 1650825000
# Successfully saved messages to s3://itversitydata/messages/part-12fa8632-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650825000 and 1650911400
# Successfully saved messages to s3://itversitydata/messages/part-2d6326f0-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650911400 and 1650997800
# Processing in range between 1650911400 and 1650997800 using token 17089699510451688957
# Successfully saved messages to s3://itversitydata/messages/part-532dd0d8-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1650997800 and 1651084200
# Successfully saved messages to s3://itversitydata/messages/part-72a513f4-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651084200 and 1651170600
# Processing in range between 1651084200 and 1651170600 using token 10568164886224780751
# Successfully saved messages to s3://itversitydata/messages/part-997cc01c-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651170600 and 1651257000
# Successfully saved messages to s3://itversitydata/messages/part-b73e1448-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651257000 and 1651343400
# Successfully saved messages to s3://itversitydata/messages/part-cd541bf6-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651343400 and 1651429800
# Successfully saved messages to s3://itversitydata/messages/part-de29e686-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651429800 and 1651516200
# Successfully saved messages to s3://itversitydata/messages/part-fa6f75ea-d440-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651516200 and 1651602600
# Successfully saved messages to s3://itversitydata/messages/part-17d34e9a-d441-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651602600 and 1651689000
# Processing in range between 1651602600 and 1651689000 using token 00999316154172414770
# Successfully saved messages to s3://itversitydata/messages/part-3b102590-d441-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651689000 and 1651775400
# Processing in range between 1651689000 and 1651775400 using token 07107691142202445665
# Successfully saved messages to s3://itversitydata/messages/part-5d5b168c-d441-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651775400 and 1651861800
# Successfully saved messages to s3://itversitydata/messages/part-7ae0a9e2-d441-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651861800 and 1651948200
# Successfully saved messages to s3://itversitydata/messages/part-8f3359bc-d441-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1651948200 and 1652034600
# Successfully saved messages to s3://itversitydata/messages/part-a2427e52-d441-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1652034600 and 1652121000
# Successfully saved messages to s3://itversitydata/messages/part-c25517b8-d441-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1652121000 and 1652207400
# Successfully saved messages to s3://itversitydata/messages/part-e3c165aa-d441-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1652207400 and 1652293800
# Successfully saved messages to s3://itversitydata/messages/part-0490c366-d442-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1652293800 and 1652380200
# Successfully saved messages to s3://itversitydata/messages/part-24aea1ea-d442-11ec-b424-3e22fbd03f7b.json
# Processing in range between 1652380200 and 1652466600
# Processing in range between 1652380200 and 1652466600 using token 13440348824091048222
# Successfully saved messages to s3://itversitydata/messages/part-452f752a-d442-11ec-b424-3e22fbd03f7b.json
# CPU times: user 23.2 s, sys: 3.02 s, total: 26.3 s
# Wall time: 34min 28s

# %%
# !aws s3 ls s3://itversitydata/messages/
