# 2022-05-16 06:16:57    4458902 part-afb0d054-d4b1-11ec-a603-e79808170361.json
# 2022-05-16 05:26:52    2567632 part-b0b06cbd-d4aa-11ec-a8ae-7b9a7ee0bd59.json
# 2022-05-16 06:52:52    3350091 part-b4623705-d4b6-11ec-aed9-e79808170361.json
# 2022-05-16 06:02:58    5153782 part-bb76f434-d4af-11ec-bedd-e79808170361.json
# 2022-05-16 08:54:48     124366 part-bcec87d0-d4c7-11ec-941c-350bffe5e5eb.json
# 2022-05-16 06:38:52    2803305 part-bf8f67c0-d4b4-11ec-a7f2-e79808170361.json
# 2022-05-16 05:48:57    5811153 part-c65e095c-d4ad-11ec-8d92-e79808170361.json
# 2022-05-16 06:24:52    2014162 part-caa02222-d4b2-11ec-ae5b-e79808170361.json
# 2022-05-16 06:10:52    2338288 part-d61d06a1-d4b0-11ec-968c-e79808170361.json
# 2022-05-16 05:35:11    5007421 part-d9c7b23c-d4ab-11ec-b0ae-e79808170361.json
# 2022-05-16 06:46:57    4577606 part-e0bd15fe-d4b5-11ec-bad0-e79808170361.json
# 2022-05-16 05:56:52    3052906 part-e1c70039-d4ae-11ec-a246-e79808170361.json
# 2022-05-16 05:42:53    2686858 part-ed6b81f7-d4ac-11ec-9468-e79808170361.json
# 2022-05-16 06:33:00    5623296 part-edb8f599-d4b3-11ec-9798-e79808170361.json
# 2022-05-16 05:28:51    2139674 part-f7cf76de-d4aa-11ec-8910-7b9a7ee0bd59.json
# 2022-05-16 06:19:00    5922563 part-f8e047f0-d4b1-11ec-acb0-e79808170361.json

# %%
import boto3

# %%
dynamodb = boto3.resource('dynamodb')

# %%
itr = dynamodb.tables.iterator()

# %%
for table in itr:
    print(table)
# Out:
# dynamodb.Table(name='emails')
# dynamodb.Table(name='ghmarker')
# dynamodb.Table(name='ghrepos')
# dynamodb.Table(name='gmail_job_run_details')
# dynamodb.Table(name='gmail_jobs')
# dynamodb.Table(name='posts')

# %%
gmail_jobs_table = dynamodb.Table('gmail_jobs')

# %%
gmail_jobs_table.scan()
# Out:
# {'Items': [{'job_description': 'Ingest data from gmail to s3',
#    'is_active': 'Y',
#    'job_id': 'gmail_ingest',
#    'baseline_days': Decimal('45'),
#    'job_run_bookmark_details': {'last_run_max_message_id': '180c8150adc6c04d',
#     'last_run_start_time_epoch': Decimal('1652627315'),
#     'last_run_end_time_epoch': Decimal('1652627343')}}],
#  'Count': 1,
#  'ScannedCount': 1,
#  'ResponseMetadata': {'RequestId': 'FG91GAV4UV0L86KSSNKB8831R7VV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Sun, 15 May 2022 15:09:16 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '352',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'FG91GAV4UV0L86KSSNKB8831R7VV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '218427899'},
#   'RetryAttempts': 0}}

# %%
gmail_job_run_details_table = dynamodb.Table('gmail_job_run_details')

# %%
gmail_job_run_details_table.scan()
# Out:
# {'Items': [{'job_id': 'gmail_ingest',
#    'job_run_bookmark_details': {'last_message_id': '17e144500cc9efec',
#     'last_message_start_time': Decimal('1641011400'),
#     'last_message_end_time': Decimal('1641018600')},
#    'rows_processed': Decimal('0'),
#    'job_run_time': Decimal('1652327576')},
#   {'job_id': 'gmail_ingest',
#    'file_name': 'part-a6cbde8e-d331-11ec-8adf-3e22fbd03f7b.json',
#    'job_run_bookmark_details': {'start_time_epoch': Decimal('1648578600'),
#     'end_time_epoch': Decimal('1648665000'),
#     'max_message_id': '17fdc0b349836c2f'},
#    'rows_processed': Decimal('73'),
#    'job_run_time': Decimal('1652497040')},
#   {'job_id': 'gmail_ingest',
#    'file_name': 'part-449e5e02-d332-11ec-8adf-3e22fbd03f7b.json',
#    'job_run_bookmark_details': {'start_time_epoch': Decimal('1648665000'),
#     'end_time_epoch': Decimal('1648751400'),
#     'max_message_id': '17fe13d6a865bbdd'},
#    'rows_processed': Decimal('80'),
#    'job_run_time': Decimal('1652497297')}],
#  'Count': 3,
#  'ScannedCount': 3,
#  'ResponseMetadata': {'RequestId': '2TQS270PTH9NUIDA27I5H9BT2BVV4KQNSO5AEMVJF66Q9ASUAAJG',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'Server',
#    'date': 'Sat, 14 May 2022 04:55:24 GMT',
#    'content-type': 'application/x-amz-json-1.0',
#    'content-length': '921',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '2TQS270PTH9NUIDA27I5H9BT2BVV4KQNSO5AEMVJF66Q9ASUAAJG',
#    'x-amz-crc32': '2969677988'},
#   'RetryAttempts': 0}}

# %%
import pandas as pd

# %%
df = pd.read_json('s3://itversitydata/messages/part-02dced21-d4b0-11ec-a5b7-e79808170361.json', orient='records')

# %%
df
# Out:
#                   id          threadId                              labelIds  \
# 0   1804e8bfa1e388ab  1804e8bfa1e388ab     [UNREAD, CATEGORY_UPDATES, INBOX]
# 1   1804e874c82ab825  1804e8718fe5e0a1              [IMPORTANT, SENT, INBOX]
# 2   1804e80547bcd9df  1804e80547bcd9df     [UNREAD, CATEGORY_UPDATES, INBOX]
# 3   1804e3c476869584  1804e3c476869584  [CATEGORY_PROMOTIONS, UNREAD, INBOX]
# 4   1804e236d3d66407  1804e236d3d66407     [UNREAD, CATEGORY_UPDATES, INBOX]
# ..               ...               ...                                   ...
# 94  18049bdec7ed1103  18049bdec7ed1103     [UNREAD, CATEGORY_UPDATES, INBOX]
# 95  18049864689dc8f0  18049864689dc8f0  [CATEGORY_PROMOTIONS, UNREAD, INBOX]
# 96  18049851003d7446  18049851003d7446     [UNREAD, CATEGORY_UPDATES, INBOX]
# 97  180497c3c9ce50bf  180497c3c9ce50bf     [UNREAD, CATEGORY_UPDATES, INBOX]
# 98  180496b3517b97e5  180496b3517b97e5  [CATEGORY_PROMOTIONS, UNREAD, INBOX]
#
#                                               snippet  \
# 0   Total ₹814.31 April 22, 2022 Thanks for riding...
# 1
# 2   Confirmation iCloud+ with 50 GB of Storage 1 m...
# 3   Find a new favorite in your local area. Uber E...
# 4   Hi Durga Viswanatha Raju, There is a new respo...
# ..                                                ...
# 94  Hi Durga Gadiraju, Raj Vegiraju has joined you...
# 95  Collaborate easily, work right in your browser...
# 96  Daily Newsletter Thursday, 21st April 2022 Who...
# 97  A payout for $20.27 is on its way to the bank ...
# 98  Early Bird AND Military Specials available now...
#
#                                               payload  sizeEstimate  \
# 0   {'partId': '', 'mimeType': 'text/html', 'filen...        102185
# 1   {'partId': '', 'mimeType': 'multipart/mixed', ...        780652
# 2   {'partId': '', 'mimeType': 'multipart/alternat...         20779
# 3   {'partId': '', 'mimeType': 'text/html', 'filen...         48367
# 4   {'partId': '', 'mimeType': 'text/html', 'filen...         13483
# ..                                                ...           ...
# 94  {'partId': '', 'mimeType': 'text/html', 'filen...         15763
# 95  {'partId': '', 'mimeType': 'multipart/alternat...         30746
# 96  {'partId': '', 'mimeType': 'text/html', 'filen...         34734
# 97  {'partId': '', 'mimeType': 'multipart/alternat...         45609
# 98  {'partId': '', 'mimeType': 'multipart/alternat...        119299
#
#     historyId   internalDate
# 0    11896250  1650585237000
# 1    11895329  1650584930000
# 2    11896388  1650584474000
# 3    11895007  1650580014000
# 4    11895053  1650578384000
# ..        ...            ...
# 94   11889749  1650504623000
# 95   11889906  1650500971000
# 96   11889748  1650500896000
# 97   11889747  1650500319000
# 98   11889905  1650499190000
#
# [99 rows x 8 columns]

# %%
df = pd.read_json('s3://itversitydata/messages/part-449e5e02-d332-11ec-8adf-3e22fbd03f7b.json', orient='records')

# %%
df
# Out:
#                   id          threadId                               labelIds  \
# 0   17fe13d6a865bbdd  17fe13d6a865bbdd   [CATEGORY_PROMOTIONS, UNREAD, INBOX]
# 1   17fe13b16f4ddaed  17fe13b16f4ddaed      [UNREAD, CATEGORY_UPDATES, INBOX]
# 2   17fe139249253b0f  17fe139249253b0f      [UNREAD, CATEGORY_UPDATES, INBOX]
# 3   17fe13846b379b6a  17fe13846b379b6a   [CATEGORY_PROMOTIONS, UNREAD, INBOX]
# 4   17fe12c9d9ae45f8  17f4b157a159f04e   [IMPORTANT, CATEGORY_UPDATES, INBOX]
# ..               ...               ...                                    ...
# 75  17fdc58fd5585c10  17fdc58fd5585c10   [CATEGORY_PROMOTIONS, UNREAD, INBOX]
# 76  17fdc3d2299bc13d  17fd86a387ddd985  [IMPORTANT, CATEGORY_PERSONAL, INBOX]
# 77  17fdc3cac00c5bae  17fdc3cac00c5bae      [UNREAD, CATEGORY_UPDATES, INBOX]
# 78  17fdc318f7e26353  17fdc318f7e26353      [UNREAD, CATEGORY_UPDATES, INBOX]
# 79  17fdc1b631fd012e  17fdc1b631fd012e       [UNREAD, CATEGORY_SOCIAL, INBOX]
#
#                                               snippet  \
# 0   Early Bird AND Military Specials end at midnig...
# 1   LinkedIn 1 new message awaits your response Li...
# 2   Save your seat! ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ...
# 3   Events, events, and more events! If you&#39;ve...
# 4   Hi Omkar and Asasri, I enjoyed meeting with yo...
# ..                                                ...
# 75  Shop hot coupons and promo codes to score toda...
# 76  I am tied up till April 18th sir. I am sorry, ...
# 77  spring cleaning. ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌...
# 78  Check out these features built for your effici...
# 79  Sravani Nagineni requested to join ITVersity (...
#
#                                               payload  sizeEstimate  \
# 0   {'partId': '', 'mimeType': 'multipart/alternat...        106192
# 1   {'partId': '', 'mimeType': 'multipart/alternat...         37769
# 2   {'partId': '', 'mimeType': 'multipart/alternat...         45393
# 3   {'partId': '', 'mimeType': 'multipart/alternat...        123844
# 4   {'partId': '', 'mimeType': 'multipart/alternat...         21953
# ..                                                ...           ...
# 75  {'partId': '', 'mimeType': 'multipart/mixed', ...        106336
# 76  {'partId': '', 'mimeType': 'multipart/alternat...          8378
# 77  {'partId': '', 'mimeType': 'multipart/alternat...         83954
# 78  {'partId': '', 'mimeType': 'multipart/alternat...         64964
# 79  {'partId': '', 'mimeType': 'multipart/alternat...         28445
#
#     historyId   internalDate
# 0    11776512  1648751371000
# 1    11776179  1648751211000
# 2    11776178  1648751071000
# 3    11776511  1648751035000
# 4    11811451  1648750234000
# ..        ...            ...
# 75   11776485  1648669293000
# 76   11774089  1648667457000
# 77   11776148  1648667437000
# 78   11776147  1648666709000
# 79   11776260  1648665255000
#
# [80 rows x 8 columns]
